# %% [markdown]
# <a href="https://colab.research.google.com/github/kimwoonggon/SIIM-COVID19-KAGGLE/blob/main/(Fold2)Study(512Image_%2B_Effb3a_%2B_NoAnnealing)Pytorch_covid19_withmask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
fold=2

# %%
os.listdir("gdrive/MyDrive/Colab Notebooks/KAGGLE_COVID_TORCH_STUDY")
# Out:
# ['include.py', 'covid19-study-colab.zip']

# %%
# !cp -r gdrive/MyDrive/Colab\ Notebooks/KAGGLE_COVID_TORCH_STUDY .

# %%
cd KAGGLE_COVID_TORCH_STUDY
# Out:
# /content/KAGGLE_COVID_TORCH_STUDY

# %%
# !unzip covid19-study-colab.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: covid19-study-colab/data/train_full_512/eea23b9c3495.png
#  extracting: covid19-study-colab/data/train_full_512/eea28baa7c69.png
#  extracting: covid19-study-colab/data/train_full_512/eea3a910fa9e.png
#  extracting: covid19-study-colab/data/train_full_512/eeacf871f2a9.png
#  extracting: covid19-study-colab/data/train_full_512/eedd7a853545.png
#  extracting: covid19-study-colab/data/train_full_512/eeee42a62e29.png
#  extracting: covid19-study-colab/data/train_full_512/eeef8cafe0b0.png
#  extracting: covid19-study-colab/data/train_full_512/eef3a0e47dc9.png
#  extracting: covid19-study-colab/data/train_full_512/eef757610245.png
#   inflating: covid19-study-colab/data/train_full_512/eef9600e5493.png
#  extracting: covid19-study-colab/data/train_full_512/eefa0243dac0.png
#  extracting: covid19-study-colab/data/train_full_512/ef0a3da0389f.png
#  extracting: covid19-study-colab/data/train_full_512/ef0cc8c0e7a5.png
# ...

# %%
cd covid19-study-colab
# Out:
# /content/KAGGLE_COVID_TORCH_STUDY/covid19-study-colab

# %%
# !pip install pydicom
# !pip install madgrad
# !pip install timm
# Out:
# ...
#      |████████████████████████████████| 1.9MB 11.8MB/s
# ...
#      |████████████████████████████████| 378kB 12.2MB/s
# ...

# %%
os.listdir()
# Out:
# ['fold0_run_submit.py',
#  'df_fold_rand830.csv',
#  'siim.cpython-37.pyc',
#  'configure.py',
#  'model_effv2_m.py',
#  'utility',
#  'model.py',
#  'freeze_original_run_train.py',
#  'fold3_run_submit.py',
#  'fold1_run_submit.py',
#  'fold4_run_submit.py',
#  'net',
#  'augmentation.py',
#  'augmentation2.py',
#  'fold2_run_submit.py',
#  'model_effv2_large.py',
#  'colab_original_augment_run_train.py',
#  'common.py',
#  'common.cpython-37.pyc',
#  'df_meta.csv',
#  'link',
#  'augmentation2.cpython-37.pyc',
#  'siim.py',
#  'duplicate.txt',
#  'fold4_original_augment_run_train.py',
#  '__init__.py',
#  'fold2_original_augment_run_train.py',
#  'sample_submission.csv',
#  'fold1_original_augment_run_train.py',
#  'run_train.py',
#  'train_image_level.csv',
#  'train_study_level.csv',
#  'run_submit.py',
#  'fold3_original_augment_run_train.py',
#  '__pycache__',
#  'original_augment_run_train.py',
#  'model_eff_v2_rw_m copy.py',
#  'dataset.py',
# ...

# %%
# !python fold{fold}_original_augment_run_train.py
# Out:
# fold 2 has started
#
# --- [START 2021-07-07_18-07-42] ----------------------------------------------------------------
#
# 	@common.py:
# 	pytorch
# 		seed = 1625681267
# 		torch.__version__              = 1.9.0+cu102
# 		torch.version.cuda             = 10.2
# 		torch.backends.cudnn.version() = 7605
# 		os['CUDA_VISIBLE_DEVICES']     = 0
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.get_device_properties() = (name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
#
#
# 	__file__ = fold2_original_augment_run_train.py
# 	out_dir  = data
#
# train_dataset :
# 	len = 4984
# 	df  = (4984, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:  1371 (0.2751)
# 		 1         Typical Appearance:  2362 (0.4739)
# 		 2   Indeterminate Appearance:   868 (0.1742)
# 		 3        Atypical Appearance:   383 (0.0768)
#
# valid_dataset :
# 	len = 1243
# 	df  = (1243, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:   338 (0.2719)
# ...

# %%
os.listdir("data/checkpoint")

# %%
# !cp -r data/checkpoint ../../gdrive/MyDrive/Colab\ Notebooks/!cp -r data/checkpoint ../../gdrive/MyDrive/Colab\ Notebooks/KAGGLE_COVID_TORCH_STUDYID_TORCH

# %%
# !python fold{fold}_run_submit.py

# %%
from timm.models.efficientnet import *

# %%
efficientnetv2_rw_m

# %%
test_net = efficientnetv2_rw_m(pretrained=True, drop_rate=0.3, drop_path_rate=0.2)

# %%
len(test_net.blocks)
# Out:
# 6

# %%
test_net
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch

# %%
test_net.blocks[5]
# Out:
# Sequential(
#   (0): InvertedResidual(
#     (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): SiLU(inplace=True)
#     (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=1152, bias=False)
#     (bn2): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act2): SiLU(inplace=True)
#     (se): SqueezeExcite(
#       (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#       (act1): SiLU(inplace=True)
#       (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#       (gate): Sigmoid()
#     )
#     (conv_pwl): Conv2d(1152, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): InvertedResidual(
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-f70db8e0-8827-4b41-a9ce-cb6fb2012d5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f70db8e0-8827-4b41-a9ce-cb6fb2012d5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_eff_v2_rw_m.py to model_eff_v2_rw_m.py
# ...

# %%
os.remove("model.py")

# %%
os.rename("model_eff_v2_rw_m.py", "model.py")

# %%
# !python run_train.py
# Out:
# fold 0 has started
#
# --- [START 2021-07-05_14-12-13] ----------------------------------------------------------------
#
# 	@common.py:
# 	pytorch
# 		seed = 1625494335
# 		torch.__version__              = 1.9.0+cu102
# 		torch.version.cuda             = 10.2
# 		torch.backends.cudnn.version() = 7605
# 		os['CUDA_VISIBLE_DEVICES']     = 0
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.get_device_properties() = (name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
#
#
# 	__file__ = run_train.py
# 	out_dir  = data
#
# train_dataset :
# 	len = 4980
# 	df  = (4980, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:  1366 (0.2743)
# 		 1         Typical Appearance:  2367 (0.4753)
# 		 2   Indeterminate Appearance:   864 (0.1735)
# 		 3        Atypical Appearance:   383 (0.0769)
#
# valid_dataset :
# 	len = 1247
# 	df  = (1247, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:   343 (0.2751)
# ...

# %%
testv2 = tf_efficientnetv2_m(pretrained=True, drop_rate=0.3, drop_path_rate=0.2)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-effv2-weights/tf_efficientnetv2_m-cc09e0cd.pth" to /root/.cache/torch/hub/checkpoints/tf_efficientnetv2_m-cc09e0cd.pth

# %%
testv2.blocks[5]
# Out:
# Sequential(
#   (0): InvertedResidual(
#     (conv_pw): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): SiLU(inplace=True)
#     (conv_dw): Conv2dSame(1056, 1056, kernel_size=(3, 3), stride=(2, 2), groups=1056, bias=False)
#     (bn2): BatchNorm2d(1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (act2): SiLU(inplace=True)
#     (se): SqueezeExcite(
#       (conv_reduce): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#       (act1): SiLU(inplace=True)
#       (conv_expand): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#       (gate): Sigmoid()
#     )
#     (conv_pwl): Conv2d(1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): InvertedResidual(
# ...

# %%
testv2
# Out:
# EfficientNet(
#   (conv_stem): Conv2dSame(3, 24, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#       )
#       (1): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#       )
#       (2): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-9a96b805-dd9a-4541-b1de-e5e3c5788a9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a96b805-dd9a-4541-b1de-e5e3c5788a9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_effv2_m.py to model_effv2_m.py
# ...

# %%
os.remove("model.py")

# %%
os.rename("model_effv2_m.py", "model.py")

# %%
# !python run_train.py
# Out:
# fold 0 has started
#
# --- [START 2021-07-05_15-13-37] ----------------------------------------------------------------
#
# 	@common.py:
# 	pytorch
# 		seed = 1625498018
# 		torch.__version__              = 1.9.0+cu102
# 		torch.version.cuda             = 10.2
# 		torch.backends.cudnn.version() = 7605
# 		os['CUDA_VISIBLE_DEVICES']     = 0
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.get_device_properties() = (name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
#
#
# 	__file__ = run_train.py
# 	out_dir  = data
#
# train_dataset :
# 	len = 4980
# 	df  = (4980, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:  1366 (0.2743)
# 		 1         Typical Appearance:  2367 (0.4753)
# 		 2   Indeterminate Appearance:   864 (0.1735)
# 		 3        Atypical Appearance:   383 (0.0769)
#
# valid_dataset :
# 	len = 1247
# 	df  = (1247, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:   343 (0.2751)
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-811558fa-18bc-4624-a9db-e68a4fdfd9d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-811558fa-18bc-4624-a9db-e68a4fdfd9d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_effv2_large.py to model_effv2_large.py
# ...

# %%
os.remove("model.py")

# %%
os.path.exists("model.py")
# Out:
# True

# %%
os.rename("model_effv2_large.py", "model.py")

# %%
# !python run_train.py
# Out:
# fold 0 has started
#
# --- [START 2021-07-05_15-52-35] ----------------------------------------------------------------
#
# 	@common.py:
# 	pytorch
# 		seed = 1625500356
# 		torch.__version__              = 1.9.0+cu102
# 		torch.version.cuda             = 10.2
# 		torch.backends.cudnn.version() = 7605
# 		os['CUDA_VISIBLE_DEVICES']     = 0
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.get_device_properties() = (name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
#
#
# 	__file__ = run_train.py
# 	out_dir  = data
#
# train_dataset :
# 	len = 4980
# 	df  = (4980, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:  1366 (0.2743)
# 		 1         Typical Appearance:  2367 (0.4753)
# 		 2   Indeterminate Appearance:   864 (0.1735)
# 		 3        Atypical Appearance:   383 (0.0769)
#
# valid_dataset :
# 	len = 1247
# 	df  = (1247, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:   343 (0.2751)
# ...

# %%
os.remove("model.py")

# %%
files.upload()
# Out:
#      <input type="file" id="files-739aa0de-ecec-4487-b6ff-03ef2999da8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-739aa0de-ecec-4487-b6ff-03ef2999da8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_effv2_m.py to model_effv2_m.py
# ...

# %%
os.rename("model_effv2_m.py", "model.py")

# %%
# !python run_train.py
# Out:
# fold 0 has started
#
# --- [START 2021-07-05_18-17-42] ----------------------------------------------------------------
#
# 	@common.py:
# 	pytorch
# 		seed = 1625509065
# 		torch.__version__              = 1.9.0+cu102
# 		torch.version.cuda             = 10.2
# 		torch.backends.cudnn.version() = 7605
# 		os['CUDA_VISIBLE_DEVICES']     = 0
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.get_device_properties() = (name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
#
#
# 	__file__ = run_train.py
# 	out_dir  = data
#
# train_dataset :
# 	len = 4980
# 	df  = (4980, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:  1366 (0.2743)
# 		 1         Typical Appearance:  2367 (0.4753)
# 		 2   Indeterminate Appearance:   864 (0.1735)
# 		 3        Atypical Appearance:   383 (0.0769)
#
# valid_dataset :
# 	len = 1247
# 	df  = (1247, 10)
# 	label distribution
# 		 0     Negative for Pneumonia:   343 (0.2751)
# ...
